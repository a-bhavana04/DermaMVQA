# %%
pip install clip
# Out:
# Collecting clipNote: you may need to restart the kernel to use updated packages.
#
#   Downloading clip-0.2.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py): started
#   Building wheel for clip (setup.py): finished with status 'done'
#   Created wheel for clip: filename=clip-0.2.0-py3-none-any.whl size=7017 sha256=09178d8a0f211a1205386638effd9ed7936923ca246691619436081882c510e0
#   Stored in directory: c:\users\bhav1\appdata\local\pip\cache\wheels\ab\a5\e8\c9fa20742edbccf2702dae8ee62053e6c460e961d45967b49c
# Successfully built clip
# Installing collected packages: clip
# Successfully installed clip-0.2.0

# %%
pip install ftfy regex
# Out:
# Requirement already satisfied: ftfy in c:\users\bhav1\anaconda3\envs\knowledge-graph\lib\site-packages (6.3.1)
# Requirement already satisfied: regex in c:\users\bhav1\anaconda3\envs\knowledge-graph\lib\site-packages (2024.9.11)
# Requirement already satisfied: wcwidth in c:\users\bhav1\anaconda3\envs\knowledge-graph\lib\site-packages (from ftfy) (0.2.13)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import pandas as pd
import faiss
from transformers import AutoProcessor, AutoModelForZeroShotImageClassification

processor_hf = AutoProcessor.from_pretrained("chanwkim/monet")
model_hf = AutoModelForZeroShotImageClassification.from_pretrained("chanwkim/monet")
device = "cuda" if torch.cuda.is_available() else "cpu"
model_hf.to(device)
model_hf.eval()

class MONETHuggingFaceDataset(Dataset):
    def __init__(self, image_paths, captions, processor):
        self.image_paths = image_paths
        self.captions = captions
        self.processor = processor

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image = Image.open(self.image_paths[idx]).convert("RGB")
        caption = self.captions[idx]
        inputs = self.processor(text=[caption], images=image, return_tensors="pt", padding="max_length", truncation=True)
        return {
            "pixel_values": inputs["pixel_values"].squeeze(0),
            "input_ids": inputs["input_ids"].squeeze(0),
            "attention_mask": inputs["attention_mask"].squeeze(0),
        }

# Load dataset
csv_path = "finetune_dataset.csv"
df = pd.read_csv(csv_path)
image_paths = df["filepath"].tolist()
captions = df["caption"].fillna("").tolist()

dataset = MONETHuggingFaceDataset(image_paths, captions, processor_hf)
train_size = int(0.8 * len(dataset))
val_size = int(0.1 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, val_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16)
test_loader = DataLoader(test_dataset, batch_size=16)

def extract_features(model, dataloader, device):
    model.eval()
    image_features, text_features = [], []

    with torch.no_grad():
        for batch in dataloader:
            pixel_values = batch["pixel_values"].to(device)
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)

            outputs = model(pixel_values=pixel_values, input_ids=input_ids, attention_mask=attention_mask)
            img_feats = outputs.image_embeds
            txt_feats = outputs.text_embeds

            img_feats = img_feats / img_feats.norm(dim=-1, keepdim=True)
            txt_feats = txt_feats / txt_feats.norm(dim=-1, keepdim=True)

            image_features.append(img_feats.cpu())
            text_features.append(txt_feats.cpu())

    image_features = torch.cat(image_features, dim=0)
    text_features = torch.cat(text_features, dim=0)

    return image_features, text_features


def compute_cosine_similarity(image_features, text_features):
    return torch.matmul(image_features, text_features.T)


def cross_modal_retrieval(image_features, text_features, image_paths, captions, k=5):
    similarity_matrix = compute_cosine_similarity(image_features, text_features)
    for i in range(len(image_features)):
        print(f"\nImage {i + 1}: {image_paths[i]}")
        top_text_indices = similarity_matrix[i].topk(k, largest=True).indices
        for rank, idx in enumerate(top_text_indices):
            print(f"  Rank {rank + 1}: {captions[idx]}")

    for j in range(len(text_features)):
        print(f"\nText {j + 1}: {captions[j]}")
        top_image_indices = similarity_matrix[:, j].topk(k, largest=True).indices
        for rank, idx in enumerate(top_image_indices):
            print(f"  Rank {rank + 1}: {image_paths[idx]}")

image_features, text_features = extract_features(model_hf, test_loader, device)
cross_modal_retrieval(image_features, text_features, image_paths, captions, k=5)
# Out:
# Image 1: c:/Users/bhav1/Downloads/dermavqa/images/train\11mk4th.png
#   Rank 1: hairline, seborrheic keratosis seborrheic keratosis, scalp
#   Rank 2: image, skin, visible, lesion, skin, discoloration, lesion
#   Rank 3: inflammatory, actinic keratosis, medical history
#   Rank 4: image, wrist, wrinkle fine line, visible, irregularity, image, car, changing, lesion, biopsy
#   Rank 5: image, skin, skin, coloration, dermatitis, wear
#
# Image 2: c:/Users/bhav1/Downloads/dermavqa/images/train\ih99w9.jpg
#   Rank 1: skin tag, skin tag, benign, skin lesion, raised, skin tag, benign, lesion
#   Rank 2: skin single, flat, skin, skin fair, hair, visible, irregularity, bump discoloration, mole
#   Rank 3: image, foot, itchy, varicose vein, daily, itching
#   Rank 4: image, fingernail skin, fingernail, fingernail, fingertip, skin texture, irregularity, inflammation, thick, irritant
#   Rank 5: folliculitis, follicular cyst, medical history, physical examination, skin, histopathological
#
# Image 3: c:/Users/bhav1/Downloads/dermavqa/images/train\11n62qx.jpg
#   Rank 1: acne acne, adult, sensitive, skin, dry skin, oily skin, skin irritation, topical acne
#   Rank 2: image, patch, skin, irregularity, normal light, hair, irregularity, wart, persistent, presence, wart
#   Rank 3: image, patch, redness, irregular, texture, skin, texture, painful, recurrent, genitalia, hidradenitis, systemic
#   Rank 4: image, hand top, skin bump, skin, sun exposure wash
#   Rank 5: case seborrheic, keratosis seborrheic keratosis, seborrheic keratoses, precancerous, diagnose, seborrheic keratosis, diagnosed, cancerous, seborrheic keratoses, glycolic acid
#
# Image 4: c:/Users/bhav1/Downloads/dermavqa/images/train\vk578x.jpg
#   Rank 1: image, visible, visible, skin
#   Rank 2: image, skin, left shoulder blade, skin, image case, herpes zoster, localised, rash, varicella chickenpox, herpes zoster, herpes zoster, weak, pain, rash, secondary infection, symptom, herpes zoster aciclovir, time daily, prescribed
#   Rank 3:
#   Rank 4: inflamed, raised, bump, visible, appearance, mild, skin irritation, staph, comedonal acne, acne
#   Rank 5: purple, patch, skin condition, purpura, skin cancer, malignancy
#
# Image 5: c:/Users/bhav1/Downloads/dermavqa/images/train\zmsedx.jpg
#   Rank 1: image, skin, inflamed, wart corn, wearing, soft sol
#   Rank 2: skin, infected, human papillomavirus hpv, chronic skin condition, eczema, wart wart, contagious, skin, wart, diabetes
#   Rank 3: image, skin, left shoulder blade, skin, image case, herpes zoster, localised, rash, varicella chickenpox, herpes zoster, herpes zoster, weak, pain, rash, secondary infection, symptom, herpes zoster aciclovir, time daily, prescribed
#   Rank 4: irregularly, seborrheic keratosis, basal cell carcinoma, melanoma
#   Rank 5: inflamed, raised, bump, visible, appearance, mild, skin irritation, staph, comedonal acne, acne
#
# Image 6: c:/Users/bhav1/Downloads/dermavqa/images/train\123bko0.jpg
#   Rank 1: patch, pigmentary, freckle melanoma
#   Rank 2: redness, skin tumor, medical history
#   Rank 3: image, skin back, skin, image area, bump, skin texture, visible, hair, patch, daily
#   Rank 4: image, hair, bump, hand painful, itchy, irritant, contact dermatitis
#   Rank 5: lesion, melanoma melanoma, malignant tumor, dark, redness crusting, combination, medical history, detection
#
# Image 7: c:/Users/bhav1/Downloads/dermavqa/images/train\11m0l9c.jpg
#   Rank 1: image, skin, coloration, texture, skin, uneven, dryness
#   Rank 2: symptom, skin tag, skin tag, benign, discomfort
#   Rank 3: image, skin, area redness, visible pore, mouth, nasolabial fold, faint hyperpigmentation, freckle
#   Rank 4: image, irregularity, bump discoloration, apparent eczema, dry, daily, irritant
#   Rank 5: image, foot, smooth surface, ball, skin, skin sole, dry, texture, ball, pressure, soft sol
#
# Image 8: c:/Users/bhav1/Downloads/dermavqa/images/train\11htonk.jpg
#   Rank 1: black papule, melanocytic nevus, skin lesion, benign
#   Rank 2: papule, melanocytic, skin lesion, increase, melanocyte skin, benign
#   Rank 3: atrophic, decreased, skin, skin thinning, increased, skin texture, diagnosing, atrophic patch, patient history, disease
#   Rank 4: hemangioma, histopathological
#   Rank 5: eczema, contact irritant, flare, sensitive, dry skin, itchiness, swelling, sensitive, skin, improve
#
# Image 9: c:/Users/bhav1/Downloads/dermavqa/images/train\1251tnr.jpg
#   Rank 1: image, skin, pigmented, lesion, pigment, skin, detect, asymmetry, spreading, irregular, changing
#   Rank 2: skin, skin, complexion, wearing, viral infection, contagious, genitalia, hiv, std, lesion
#   Rank 3: papule, melanocytic, skin lesion, increase, melanocyte skin, benign
#   Rank 4: case plantar wart, skin infected, human papillomavirus hpv, chronic skin condition, eczema, wart wart, contagious, skin, wart, diabetes
#   Rank 5: image, medical history
#
# Image 10: c:/Users/bhav1/Downloads/dermavqa/images/train\122xd14.jpg
#   Rank 1: atrophic, decreased, skin, skin thinning, increased, skin texture, diagnosing, atrophic patch, patient history, disease
#   Rank 2: hemangioma, histopathological
#   Rank 3: image, texture, visible, nose cluster, bridge nose, appearance, skin, mild redness, irritation, laser therapy, effective
#   Rank 4: image, patch, skin, skin, inflammation, fungal infection, mild
#   Rank 5:
#
# Image 11: c:/Users/bhav1/Downloads/dermavqa/images/train\11kkilq.jpg
#   Rank 1: redness, skin tumor, medical history
#   Rank 2: image, toenail discoloration, abnormality, discoloration, healthy, smooth surface, natural curvature, skin, leakage, impact, pressure blood vessel, leakage, failure, infection
#   Rank 3: scaly, skin, hair, fever, itchy, lesion, lesion, variant psoriasis, mild, lesion
#   Rank 4: skin, infected, human papillomavirus hpv, chronic skin condition, eczema, wart wart, contagious, skin, wart, diabetes
#   Rank 5: eczema, contact irritant, flare, sensitive, dry skin, itchiness, swelling, sensitive, skin, improve
#
# Image 12: c:/Users/bhav1/Downloads/dermavqa/images/train\11idp98.jpg
#   Rank 1: black papule, symmetrical, melanocytic nevus
#   Rank 2: case pityriasis, yeast infection, skin flaky, discolored, patch, summer, infectious, family mild pityriasis versicolor, skin, pityriasis versicolor, sweat, bathing, case pityriasis, long term, rash, recurrence
#   Rank 3: presentation, small papule, color skin, medical history, skin lesion
#   Rank 4: image, visible, skin, discoloration
#   Rank 5: solar keratosis, solar keratosis, cutaneous squamous cell carcinoma, immune function, predisposing disease, actinic keratoses, increased, risk, cutaneous squamous cell carcinoma, scc actinic keratoses, risk skin cancer, actinic keratoses
#
# Image 13: c:/Users/bhav1/Downloads/dermavqa/images/train\z8b11d.jpg
#   Rank 1: image, purple discoloration, skin, reddened, flushed rest, visible area, discoloration, bruise, heals
#   Rank 2: melanocytic, skin lesion, pigment, skin
#   Rank 3: image, skin, skin, coloration, dermatitis, wear
#   Rank 4: small skin ulcer, disease, herpetic skin disease, medical history, physical examination, skin, histopathological
#   Rank 5: hairline, seborrheic keratosis seborrheic keratosis, scalp
#
# Image 14: c:/Users/bhav1/Downloads/dermavqa/images/train\11zjnov.png
#   Rank 1: image, pigmentation skin, reddened, patch, white skin, redness, blotchy, appearance, irregular, man, facial hair, skin, photodermatoses, sun exposed area, sign, prolonged, photosensitivity, disease entity, exogenous, photodermatoses, phototoxic photoallergic reaction, photosensitiser, drug photocontact dermatitis, autoimmune disease, lupus erythematosus, dermatomyositis, photosensitivity, photosensitivity, disorder, summer, effective, skin, indoors, oral
#   Rank 2: image
#   Rank 3: image, skin, texture, hair follicle, pore faint, moisture, image, mouth, skin texture, seborrheic dermatitis, scratching, daily, depigmentation cream
#   Rank 4: image, elbow redness, skin, hair, itchy, painful, dermatitis, daily
#   Rank 5: black papule, melanocytic nevus, skin lesion, benign
#
# Image 15: c:/Users/bhav1/Downloads/dermavqa/images/train\11pgkp8.jpg
#   Rank 1: case leukoderma, loss skin color, white spot, dead cell, depigmentation color loss, vitiligo, symptom, white spot, protection
#   Rank 2: image, physical examination
#   Rank 3: onychomycosis, nail disease, irregular, white spot, fungal infection, nutritional deficiency
#   Rank 4: central discoloration, raised, texture, discolored, light brown, hair, age, skin, thinned, mild, aggravated, scratching, heals
#   Rank 5: image, palm, raised, bump, skin palm, discoloration, visible, hand sweat, recurrent, hand foot
#
# Image 16: c:/Users/bhav1/Downloads/dermavqa/images/train\121yasg.jpg
#   Rank 1: image, patch, skin, irregularity, normal light, hair, irregularity, wart, persistent, presence, wart
#   Rank 2: upper limb, inflammatory, histopathological, infection
#   Rank 3: image, skin, redness, skin infected, human papillomavirus hpv, chronic skin condition, eczema, wart wart, contagious, skin, wart, diabetes
#   Rank 4: melanocytic nevus, increase, skin benign
#   Rank 5: acne acne, adult, sensitive, skin, dry skin, oily skin, skin irritation, topical acne
#
# Image 17: c:/Users/bhav1/Downloads/dermavqa/images/train\11ihen9.jpg
#   Rank 1:
#   Rank 2: physical examination
#   Rank 3: onychomycosis, nail disease, irregular, white spot, fungal infection, nutritional deficiency
#   Rank 4: image
#   Rank 5: medical history
#
# Image 18: c:/Users/bhav1/Downloads/dermavqa/images/train\11ydlds.jpg
#   Rank 1: inflammatory, actinic keratosis, medical history
#   Rank 2: image, wrist, wrinkle fine line, visible, irregularity, image, car, changing, lesion, biopsy
#   Rank 3: image, heel skin, area redness, area flaking, raised, texture, white dot, visible, appearance, inflammation
#   Rank 4: case pityriasis, yeast infection, skin flaky, discoloured, patch, summer, infectious, familymild pityriasis versicolor, skin, pityriasis versicolor, sweat, bathing, case pityriasis, long term, rash, recurrence
#   Rank 5: image, elbow, area redness, border redness, visible, mole freckle, redness arm, hair, skin, texture, skin, difficult, rash, morphea, inflammatory rash
#
# Image 19: c:/Users/bhav1/Downloads/dermavqa/images/train\xh8ial.jpg
#   Rank 1: image, skin image, wearing, red painful, fall time part
#   Rank 2: image
#   Rank 3: lesion lower limb, skin condition, purpura, urticaria, skin infection, medical history, physical examination, histopathological, vasculitis allergic reaction, skin, manifestation, viral infection
#   Rank 4: eczema, contact irritant, flare, sensitive, dry skin, itchiness, swelling, sensitive, skin, improve
#   Rank 5: lesion, melanoma melanoma, malignant tumor, dark, redness crusting, combination, medical history, detection
#
# Image 20: c:/Users/bhav1/Downloads/dermavqa/images/train\11v5s95.jpg
#   Rank 1: polypoid, protrusion, skin, symptom, skin lesion, malignancy lesion
#   Rank 2: image, purple discoloration, skin, reddened, flushed rest, visible area, discoloration, bruise, heals
#   Rank 3: image
#   Rank 4: hairline, seborrheic keratosis seborrheic keratosis, scalp
#   Rank 5: image, skin, exfoliation
#
# Image 21: c:/Users/bhav1/Downloads/dermavqa/images/train\11nt0md.jpg
#   Rank 1: image, skin, irregular, blurry, skin color, skin, texture, skin, case discoid eczema, discoid eczema, type eczemadermatitis, plaque, eczema, eruption, impetigo, contact dermatitis, dry skin, discoid eczema, atopic eczema, tinea corporis ringworm infection, discoid eczema, irritant, ringworm, superficial basal cell carcinoma
#   Rank 2: squamous cell carcinoma, squamous cell carcinoma, type skin tumor, skin, ulcer
#   Rank 3: image, visible, visible, skin
#   Rank 4: image, skin heel, thickened, friction
#   Rank 5: image, partially, freckle, bump, stretch, appearance, skin, exfoliant, itching, dryness
#
# Image 22: c:/Users/bhav1/Downloads/dermavqa/images/train\11ih6az.jpg
#   Rank 1: case plantar wart, skin infected, human papillomavirus hpv, chronic skin condition, eczema, wart wart, contagious, skin, wart, diabetes
#   Rank 2: papule, skin lesion, lesion
#   Rank 3: benign, vascular skin lesion, diagnosed, vascular laser
#   Rank 4: irregular, nodule, seborrheic keratosis melanoma, seborrheic keratosis, skin condition, irregular, head neck melanoma, malignant, skin tumor, irregularly, pigmented, patch
#   Rank 5: image, irritation, skin, irritated area, affected, irritated area, hand eczema, irritant, aggravate, mild
#
# Image 23: c:/Users/bhav1/Downloads/dermavqa/images/train\11oo3mv.jpg
#   Rank 1: presentation, inflammatory, skin condition, eczema, psoriasis, diagnostic confirmation
#   Rank 2: skin color, symptom, medical history, malignant melanoma, skin disorder
#   Rank 3: image, visible area, bend elbow, abnormality, image eczema, wear, scratching
#   Rank 4: image, fingertip, visible
#   Rank 5: presentation, symptom, skin tumor, dark, irregular, central papule, medical history, physical examination, histopathological
#
# Image 24: c:/Users/bhav1/Downloads/dermavqa/images/train\11x6mai.jpg
#   Rank 1: image, toenail, dark discoloration, skin, discolored faint, discoloration, longitudinal melanonychia, congenital nevus
#   Rank 2: image, irritation, skin, irritated area, affected, irritated area, hand eczema, irritant, aggravate, mild
#   Rank 3: foot, melanocytic nevus, histopathological, melanocytic nevus, skin condition, accumulation, pigment, benign, malignant melanoma
#   Rank 4: image, healthy, discoloration, irregularity, sebaceous material, scalp, scalp
#   Rank 5: image, skin, redness, skin infected, human papillomavirus hpv, chronic skin condition, eczema, wart wart, contagious, skin, wart, diabetes
#
# Image 25: c:/Users/bhav1/Downloads/dermavqa/images/train\nxy2zq.jpg
#   Rank 1: image, cheekbone, raised, skin, dark, wearing, irritant
#   Rank 2: image, texture, visible, nose cluster, bridge nose, appearance, skin, mild redness, irritation, laser therapy, effective
#   Rank 3: papule, skin lesion, lesion
#   Rank 4: skin, skin tag, benign, skin tag, itching
#   Rank 5: image, healthy, discoloration, irregularity, sebaceous material, scalp, scalp
#
# Image 26: c:/Users/bhav1/Downloads/dermavqa/images/train\11rbig0.png
#   Rank 1: image, lesion, thickened, skin
#   Rank 2: melanoma, histopathological
#   Rank 3: patch, manifestation, skin condition, psoriasis eczema, discoid lupus erythematosus
#   Rank 4: image, skin image, wearing, red painful, fall time part
#   Rank 5: image, interpretation, infection, hair follicle, redness, swelling, systemic
#
# Image 27: c:/Users/bhav1/Downloads/dermavqa/images/train\11ejw2c.jpg
#   Rank 1: case leukoderma, loss skin color, white spot, dead cell, depigmentation color loss, vitiligo, symptom, white spot, protection
#   Rank 2: image, physical examination
#   Rank 3: image, visible, bump, isolated, skin, neck, hormonal, acne acne, hormonal, irregular, pimple night
#   Rank 4: irregularly, medical history, symptom, skin lesion infection
#   Rank 5: image, skin, peeling skin, appearance, dryness, irritation skin peeling, irritant
#
# Image 28: c:/Users/bhav1/Downloads/dermavqa/images/train\11kj4o4.jpg
#   Rank 1: image, skin, ingrown, hair, ingrown, hair, hair, infection, hair, shave, hair, pat, skin, skin, skin, moisture, skin type, carriage, persistent
#   Rank 2: skin disorder, folliculitis furuncle, medical history, physical examination, histopathological
#   Rank 3: image, heel skin, area redness, area flaking, raised, texture, white dot, visible, appearance, inflammation
#   Rank 4: image, skin, pigmented, lesion, pigment, skin, detect, asymmetry, spreading, irregular, changing
#   Rank 5: image, hand pale complexion resting, knuckle, skin, bump, discoloration, irregularity, visible, glass kind allergy, irritant, mild
#
# Image 29: c:/Users/bhav1/Downloads/dermavqa/images/train\11h1fvq.jpg
#   Rank 1: melanoma, histopathological
#   Rank 2: image, vermilion border lip, skin skin, lip, contact dermatitis
#   Rank 3: itchy, skin itchy, skin, dry skin, atopic dermatitis, contact dermatitis, hyaluronic acid bee, improve, defect, itching
#   Rank 4:
#   Rank 5: squamous cell carcinoma, squamous cell carcinoma, type skin tumor, skin, ulcer
#
# Image 30: c:/Users/bhav1/Downloads/dermavqa/images/train\123damf.jpg
#   Rank 1: image, skin, visible, lesion, skin, discoloration, lesion
#   Rank 2: malignant melanoma, skin malignancy
#   Rank 3: inflammatory, actinic keratosis, medical history
#   Rank 4: image, wrist, wrinkle fine line, visible, irregularity, image, car, changing, lesion, biopsy
#   Rank 5: image, heel skin, area redness, area flaking, raised, texture, white dot, visible, appearance, inflammation
#
# Image 31: c:/Users/bhav1/Downloads/dermavqa/images/train\11g9d4t.jpg
#   Rank 1: image, skin, area redness, visible pore, mouth, nasolabial fold, faint hyperpigmentation, freckle
#   Rank 2: image, skin, irregular, blurry, skin color, skin, texture, skin, case discoid eczema, discoid eczema, type eczemadermatitis, plaque, eczema, eruption, impetigo, contact dermatitis, dry skin, discoid eczema, atopic eczema, tinea corporis ringworm infection, discoid eczema, irritant, ringworm, superficial basal cell carcinoma
#   Rank 3: black papule, excessive, seborrheic keratosis
#   Rank 4: symmetrical, skin tag, skin tag, benign, skin lesion, medical advice
#   Rank 5: pilomatrixoma, histopathological
#
# Image 32: c:/Users/bhav1/Downloads/dermavqa/images/train\123nkqb.jpg
#   Rank 1: inadequate, image
#   Rank 2: fibrokeratoma, genetic skin disorder, appearance, excessive, wartlike lesion
#   Rank 3: upper limb, inflammatory, histopathological, infection
#   Rank 4: image, scalp, patch, hair follicle, patch, base hair shaft, skin, visible redness, inflammation, irregularity, hair, dark, hair breakage, visible area
#   Rank 5: image, skin, redness, skin infected, human papillomavirus hpv, chronic skin condition, eczema, wart wart, contagious, skin, wart, diabetes
#
# Image 33: c:/Users/bhav1/Downloads/dermavqa/images/train\11e8p16.png
#   Rank 1: itchy, skin itchy, skin, dry skin, atopic dermatitis, contact dermatitis, hyaluronic acid bee, improve, defect, itching
#   Rank 2: inflamed, raised, bump, visible, appearance, mild, skin irritation, staph, comedonal acne, acne
#   Rank 3: image, visible, visible, skin
#   Rank 4: skin, histopathology
#   Rank 5: melanoma, histopathological
#
# Image 34: c:/Users/bhav1/Downloads/dermavqa/images/train\1246orr.jpg
#   Rank 1: image, skin, ingrown, hair, ingrown, hair, hair, infection, hair, shave, hair, pat, skin, skin, skin, moisture, skin type, carriage, persistent
#   Rank 2: black papule, excessive, skin, thickening stratum corneum, affected
#   Rank 3: smooth red nodule, furuncle
#   Rank 4: chronic, smoking, line wrinkle skin, improve, skin, texture, pigment, hydration, wrinkle, injection soft tissue
#   Rank 5: image, skin, multiple, oral, spider angioma
#
# Image 35: c:/Users/bhav1/Downloads/dermavqa/images/train\11l634h.jpg
#   Rank 1: image, texture, visible, nose cluster, bridge nose, appearance, skin, mild redness, irritation, laser therapy, effective
#   Rank 2: skin tumor, actinic keratosis, histopathological
#   Rank 3: inadequate, image
#   Rank 4: rash, mast cell, inflammatory, systemic symptom, symptom diarrhea, shortness breath
#   Rank 5: image, skin, visible, skin, texture, image, black coloration pink, skin cancer, biopsy, benign angioma, decision
#
# Image 36: c:/Users/bhav1/Downloads/dermavqa/images/train\11h44rx.jpg
#   Rank 1: inflamed, raised, bump, visible, appearance, mild, skin irritation, staph, comedonal acne, acne
#   Rank 2: image, skin neck, skin, skin tag
#   Rank 3: image, skin, texture, discoloration, patch, discolored, patch, patch, patch, raised, texture, irritation, discolored, rash, scratching, biopsy
#   Rank 4: skin, histopathology
#   Rank 5: image, cheekbone, raised, skin, dark, wearing, irritant
#
# Image 37: c:/Users/bhav1/Downloads/dermavqa/images/train\11zgkmn.jpg
#   Rank 1: skin, skin tag, benign, skin tag, itching
#   Rank 2: image, skin, left shoulder blade, skin, image case, herpes zoster, localised, rash, varicella chickenpox, herpes zoster, herpes zoster, weak, pain, rash, secondary infection, symptom, herpes zoster aciclovir, time daily, prescribed
#   Rank 3: image, fingernail skin, fingernail, fingernail, fingertip, skin texture, irregularity, inflammation, thick, irritant
#   Rank 4: irregularly, medical history, symptom, skin lesion infection
#   Rank 5: dry thickened, cracking, hard skin
#
# Image 38: c:/Users/bhav1/Downloads/dermavqa/images/train\11jxuv5.png
#   Rank 1: image, skin, flat, skin, irregular, skin cancer, mole fit, changing, biopsy
#   Rank 2: lesion, melanoma melanoma, malignant tumor, dark, redness crusting, combination, medical history, detection
#   Rank 3: lesion lower limb, skin condition, purpura, urticaria, skin infection, medical history, physical examination, histopathological, vasculitis allergic reaction, skin, manifestation, viral infection
#   Rank 4: skin tumor, medical history, skin tumor, malignant
#   Rank 5: image, abnormality, image, blurry, eczema, mouth, herpetic whitlow, herpes infection finger, oral
#
# Image 39: c:/Users/bhav1/Downloads/dermavqa/images/train\11ldo54.jpg
#   Rank 1: image, skin single, skin, appearance, skin, hair, painful
#   Rank 2: hairline, skin tumor
#   Rank 3: seborrheic keratosis seborrheic keratosis, chronic skin condition, appearance, skin, itching, pain treatment
#   Rank 4: blueblack, melanoma, malignant skin tumor
#   Rank 5: image, abnormality, image, blurry, eczema, mouth, herpetic whitlow, herpes infection finger, oral
#
# Image 40: c:/Users/bhav1/Downloads/dermavqa/images/train\11eqg2f.jpg
#   Rank 1: papule, melanocytic, skin lesion, increase, melanocyte skin, benign
#   Rank 2: image, cheek redness, normal, eczema, mild, daily
#   Rank 3: image, redness, visible pore, hair, blurry, difficult, cyst skin, acne, slowly, flaring
#   Rank 4: image, skin, pigmented, lesion, pigment, skin, detect, asymmetry, spreading, irregular, changing
#   Rank 5: image, shoulder, appearance, bump, visible area, dry skin, appearance, acne, systemic, experience, dryness, daily
#
# Image 41: c:/Users/bhav1/Downloads/dermavqa/images/train\11v2ecc.jpg
#   Rank 1: image, skin, scaly, texture, skin, hair, texture, lesion, lesion, eczema, tinea corporis, sweet syndrome, rest history, biopsy
#   Rank 2: patch, pigmentary, freckle melanoma
#   Rank 3:
#   Rank 4: skin tumor, actinic keratosis, histopathological
#   Rank 5: image, reddened, blotchy, appearance, redness, skin, uneven, texture, atopic eczema, skin condition, dry itchy, patch skin, flare, frequent, food allergy, sensitive, dry skin, itchiness, swelling, sensitive, skin, improve
#
# Image 42: c:/Users/bhav1/Downloads/dermavqa/images/train\1162b7j.jpg
#   Rank 1: black papule, symmetrical, melanocytic nevus
#   Rank 2: image, skin, pigmented, lesion, pigment, skin, detect, asymmetry, spreading, irregular, changing
#   Rank 3: case pityriasis, yeast infection, skin flaky, discolored, patch, summer, infectious, family mild pityriasis versicolor, skin, pityriasis versicolor, sweat, bathing, case pityriasis, long term, rash, recurrence
#   Rank 4: colored papule, medical history, morphology, symptom skin lesion, papule, hairline, folliculitis eczema dermatitis
#   Rank 5: image, visible, skin, discoloration
#
# Image 43: c:/Users/bhav1/Downloads/dermavqa/images/train\1266hp1.jpg
#   Rank 1: image, skin, image dryness, lesion, keratotis pilaris
#   Rank 2: image, patch, skin, texture, pale center, irregularity, discoloration, visual, dry, fungal infection, eczema, fungal infection, dry
#   Rank 3: image
#   Rank 4: image, scaly, texture, pink, affected, skin, skin, skin texture, nummular eczema, lesion
#   Rank 5: image, skin, pigmented, lesion, pigment, skin, detect, asymmetry, spreading, irregular, changing
#
# Image 44: c:/Users/bhav1/Downloads/dermavqa/images/train\1230249.jpg
#   Rank 1: seborrheic keratosis, skin condition, excessive, skin, abnormal, blackhead
#   Rank 2: pigmented, patch, melanoma melanoma, malignant skin tumor, irregular, skin lesion, progression, metastasis
#   Rank 3: image, scalp, brown hair, visible, scalp, skin scalp, hair follicle, fair skin, mole, changing
#   Rank 4: lesion, melanoma melanoma, malignant tumor, dark, redness crusting, combination, medical history, detection
#   Rank 5: image, skin, left shoulder blade, skin, image case, herpes zoster, localised, rash, varicella chickenpox, herpes zoster, herpes zoster, weak, pain, rash, secondary infection, symptom, herpes zoster aciclovir, time daily, prescribed
#
# Image 45: c:/Users/bhav1/Downloads/dermavqa/images/train\11rljbj.jpg
#   Rank 1: image, skin single, skin, appearance, skin, hair, painful
#   Rank 2: hairline, skin tumor
#   Rank 3: asymmetrical, melanocytic nevus
#   Rank 4: blueblack, melanoma, malignant skin tumor
#   Rank 5: seborrheic keratosis seborrheic keratosis, chronic skin condition, appearance, skin, itching, pain treatment
#
# Image 46: c:/Users/bhav1/Downloads/dermavqa/images/train\12848w3.jpg
#   Rank 1: image, diffuse, erythema, skin, skin, patch, corner mouth, chronic inflammatory skin condition, age, rosacea, persistent, facial redness, relapsing, symptom controlled, depression hypertension, cardiovascular disease, rheumatoid arthritis, helicobacter pylorus infection, ulcerative colitis, dementia, trigger, mild, protection, exfoliants, aggravate, appearance, redness, vascular laser, oral, oral, low dose refractory disease, rosacea, chronic disease, relapsing, symptom
#   Rank 2: image, concentration redness, visible, reddened area
#   Rank 3: image, skin, image dryness, lesion, keratotis pilaris
#   Rank 4: papule, melanocytic, skin lesion, increase, melanocyte skin, benign
#   Rank 5: image, toenail, dark discoloration, skin, discolored faint, discoloration, longitudinal melanonychia, congenital nevus
#
# Image 47: c:/Users/bhav1/Downloads/dermavqa/images/train\124lin7.jpg
#   Rank 1: image, skin, texture, hair follicle, pore faint, moisture, image, mouth, skin texture, seborrheic dermatitis, scratching, daily, depigmentation cream
#   Rank 2: chronic, smoking, line wrinkle skin, improve, skin, texture, pigment, hydration, wrinkle, injection soft tissue
#   Rank 3: keratotic papule, upper limb, skin condition, keratotic papule scale skin, medical history, physical examination, skin, histopathology
#   Rank 4: irregularly, seborrheic keratosis, basal cell carcinoma, melanoma
#   Rank 5: image, elbow redness, skin, hair, itchy, painful, dermatitis, daily
#
# Image 48: c:/Users/bhav1/Downloads/dermavqa/images/train\126al5y.jpg
#   Rank 1: case leukoderma, loss skin color, white spot, dead cell, depigmentation color loss, vitiligo, symptom, white spot, protection
#   Rank 2: image, skin bump, appearance, skin, uneven, irritated, fever, rash, itch, rash, spreading, itch, itch, daily
#   Rank 3: image, skin, texture, hair, skin, irregularity, image, symptom itching, dicomfort, rash, eczema, atopic dermatitis, contact dermatitis, allergic sensitive, skin walking, heat rash, vera, harsh
#   Rank 4: image, scaly, texture, pink, affected, skin, skin, skin texture, nummular eczema, lesion
#   Rank 5: patch, pigmentary, freckle melanoma
#
# Image 49: c:/Users/bhav1/Downloads/dermavqa/images/train\115ogb6.jpg
#   Rank 1: case urticaria, flea, bedbug, infested, trigger, severe, itching
#   Rank 2: image, abnormality, image, blurry, eczema, mouth, herpetic whitlow, herpes infection finger, oral
#   Rank 3: image, fingernail skin fingertip, dry cracked, yellowish discoloration, skin, inflamed, fingernail, texture, wart periungual wart wart form, fingernail, pretty painful, infection, human papillomavirus hpv hpv, skin, wart, subungual wart, pain, wart
#   Rank 4: case leukoderma, loss skin color, white spot, dead cell, depigmentation color loss, vitiligo, symptom, white spot, protection
#   Rank 5: image, increased, redness, dryness, skin fingertip, hand eczema, keratolysis exfoliativa, change, recurrence
#
# Image 50: c:/Users/bhav1/Downloads/dermavqa/images/train\115d5pm.jpg
#   Rank 1: keratoacanthoma, histopathological, diagnosis keratoacanthoma, benign skin tumor
#   Rank 2: black papule, symmetrical, melanocytic nevus
#   Rank 3: inflamed, raised, bump, visible, appearance, mild, skin irritation, staph, comedonal acne, acne
#   Rank 4: skin, texture, hair, visible, minor skin irritation, inflammation
#   Rank 5: image, fingernail, fingernail, texture, surface discolored, fingernail, fingernail, damaged, cracked, crack, worsens, yeast infection
#
# Image 51: c:/Users/bhav1/Downloads/dermavqa/images/train\11zvn4m.png
#   Rank 1: red papule, medical history, physical examination, histopathological
#   Rank 2: image, uneven, skin, visible, appearance, skin discoloration, image, sun exposure look
#   Rank 3:
#   Rank 4: onychomycosis, nail disease, irregular, white spot, fungal infection, nutritional deficiency
#   Rank 5: image, foot, smooth surface, ball, skin, skin sole, dry, texture, ball, pressure, soft sol
#
# Image 52: c:/Users/bhav1/Downloads/dermavqa/images/train\10ljs1b.jpg
#   Rank 1: physical examination, vasculitis, effective
#   Rank 2: image, cheekbone, raised, skin, dark, wearing, irritant
#   Rank 3: irregular, lung, pulmonary infection tuberculosis, pulmonary tumor
#   Rank 4: black papule, melanocytic nevus, skin lesion, benign
#   Rank 5: inflamed, raised, bump, visible, appearance, mild, skin irritation, staph, comedonal acne, acne
#
# Image 53: c:/Users/bhav1/Downloads/dermavqa/images/train\1255vkp.jpg
#   Rank 1: image, erythema, skin, visible, affected, area redness, image, dermatitis infection, dermatitis
#   Rank 2: atrophic, decreased, skin, skin thinning, increased, skin texture, diagnosing, atrophic patch, patient history, disease
#   Rank 3: image, brown hair, skin forehead, appearance, hair loss, alopecia areata type autoimmune disorder, healthy diet, daily, interval, progressive, patch
#   Rank 4: reduce, lesion lesion, pricked
#   Rank 5: image, skin, pigmented, lesion, pigment, skin, detect, asymmetry, spreading, irregular, changing
#
# Image 54: c:/Users/bhav1/Downloads/dermavqa/images/train\11rk8rd.jpg
#   Rank 1: acne acne, adult, sensitive, skin, dry skin, oily skin, skin irritation, topical acne
#   Rank 2: image, skin, irregular, raised, texture, skin, texture, scar
#   Rank 3: image, skin, case angiofibroma, benign, vascular neoplasm, dermal, fibrous tissue, angiofibromas, benign, persistent, angiofibromas, basal cell carcinoma
#   Rank 4: image, visible, lesion discoloration
#   Rank 5: image, wrist, wrinkle fine line, visible, irregularity, image, car, changing, lesion, biopsy
#
# Image 55: c:/Users/bhav1/Downloads/dermavqa/images/train\124a8u3.jpg
#   Rank 1: image, erythema, skin, visible, affected, area redness, image, dermatitis infection, dermatitis
#   Rank 2: image, patch, skin, discoloration discoloration light pink reddishbrown, skin, dry, irregular, skin, hair, visible, image, eczematous, lesion, dry skin, aggravating factor, air, summer, prolonged, hydration, bathing, itchy, skin thicker, irritant
#   Rank 3: black patch nose basal cell carcinoma, medical history
#   Rank 4: skin tag, skin tag, skin lesion, protrusion, hyperpigmentation, benign, symptomatic
#   Rank 5: image, healthy, discoloration, irregularity, sebaceous material, scalp, scalp
#
# Image 56: c:/Users/bhav1/Downloads/dermavqa/images/train\gqr1w3.jpg
#   Rank 1: pigmented, symmetrical, melanocytic nevus, worsening, symptom
#   Rank 2: skin, skin tag, benign, skin tag, itching
#   Rank 3: irregularly, medical history, symptom, skin lesion infection
#   Rank 4: image, cheekbone, raised, skin, dark, wearing, irritant
#   Rank 5: skin, histopathology
#
# Image 57: c:/Users/bhav1/Downloads/dermavqa/images/train\11vsbt7.jpg
#   Rank 1: pigmented, melanocytic, benign, worsening, symptom
#   Rank 2: image, skin, texture, visible, visible redness, irregularity, body hair, mole
#   Rank 3: image, visible hand, skin, hair, eczema, heals
#   Rank 4: papule, skin lesion, lesion
#   Rank 5: image, abdomen, skin, navel, abdomen, skin, horizontal, wearing, uneven, abdomen, heat source, redness condition, improve, appearance
#
# Image 58: c:/Users/bhav1/Downloads/dermavqa/images/train\11vlene.png
#   Rank 1: image, patch, skin, irregularity, normal light, hair, irregularity, wart, persistent, presence, wart
#   Rank 2: upper limb, inflammatory, histopathological, infection
#   Rank 3: image, visible, lesion discoloration
#   Rank 4: image, skin, irregular, raised, texture, skin, texture, scar
#   Rank 5: image, reddish rash rash, appearance, rash, skin, rash, texture, hair, image, affected, healing itchy
#
# Image 59: c:/Users/bhav1/Downloads/dermavqa/images/train\11pw9du.jpg
#   Rank 1: skin tag, skin tag, benign, skin lesion, raised, skin tag, benign, lesion
#   Rank 2: image, angular cheilitis, rash, indefinitely, controlling, drool
#   Rank 3: image, skin, image dryness, lesion, keratotis pilaris
#   Rank 4: asymmetrical, melanocytic nevus
#   Rank 5: colored papule, medical history, morphology, symptom skin lesion, papule, hairline, folliculitis eczema dermatitis
#
# Image 60: c:/Users/bhav1/Downloads/dermavqa/images/train\11lv9ax.jpg
#   Rank 1: image, irritation, skin, irritated area, affected, irritated area, hand eczema, irritant, aggravate, mild
#   Rank 2: image, toenail, dark discoloration, skin, discolored faint, discoloration, longitudinal melanonychia, congenital nevus
#   Rank 3: image, skin, redness, skin infected, human papillomavirus hpv, chronic skin condition, eczema, wart wart, contagious, skin, wart, diabetes
#   Rank 4: upper limb, inflammatory, histopathological, infection
#   Rank 5: purpuric spot, trauma bleeding disorder, medical condition, bruising, relief, bruise, bruise
#
# Image 61: c:/Users/bhav1/Downloads/dermavqa/images/train\11ywbdo.jpg
#   Rank 1: image, visible, lesion discoloration
#   Rank 2: image, skin, case angiofibroma, benign, vascular neoplasm, dermal, fibrous tissue, angiofibromas, benign, persistent, angiofibromas, basal cell carcinoma
#   Rank 3: image, heel skin, area redness, area flaking, raised, texture, white dot, visible, appearance, inflammation
#   Rank 4: case pityriasis, yeast infection, skin flaky, discoloured, patch, summer, infectious, familymild pityriasis versicolor, skin, pityriasis versicolor, sweat, bathing, case pityriasis, long term, rash, recurrence
#   Rank 5: image, wrist, wrinkle fine line, visible, irregularity, image, car, changing, lesion, biopsy
#
# Image 62: c:/Users/bhav1/Downloads/dermavqa/images/train\11hmoj4.jpg
#   Rank 1: image, toenail, dark discoloration, skin, discolored faint, discoloration, longitudinal melanonychia, congenital nevus
#   Rank 2: image, cheek erythema, diffuse redness, uneven, texture, erythematous area, evidence, scaling pustule, blue iris, visible, pupil eczema, irritant
#   Rank 3: image, healthy, discoloration, irregularity, sebaceous material, scalp, scalp
#   Rank 4: skin, skin, complexion, wearing, viral infection, contagious, genitalia, hiv, std, lesion
#   Rank 5: image, eyebrow eyebrow, skin, texture, irregularity, bump discoloration, image, scratching, exfoliant, pigmented, skin, irritant, weight overweight
#
# Image 63: c:/Users/bhav1/Downloads/dermavqa/images/train\11syih7.png
#   Rank 1: image, texture, visible, nose cluster, bridge nose, appearance, skin, mild redness, irritation, laser therapy, effective
#   Rank 2: skin, skin tag, benign, skin tag, itching
#   Rank 3: image, patch, irregular, palm skin, pink, patch, hair, patch, eczema, contact dermatitis
#   Rank 4: image, scalp, patch, hair follicle, patch, base hair shaft, skin, visible redness, inflammation, irregularity, hair, dark, hair breakage, visible area
#   Rank 5: patch, pigmentary, freckle melanoma
#
# Image 64: c:/Users/bhav1/Downloads/dermavqa/images/train\11t9yw6.png
#   Rank 1: sebaceous cyst squamous cell carcinoma, melanoma, medical history, lesion
#   Rank 2: pigmented, symmetrical, melanocytic nevus, worsening, symptom
#   Rank 3: image, combination, medical history, symptom, physical examination
#   Rank 4: inflammatory, actinic keratosis, inflammatory, inflammatory condition, actinic keratosis, excessive, medical history
#   Rank 5: image, dark, pupil, skin, texture, image, image, skin
#
# Image 65: c:/Users/bhav1/Downloads/dermavqa/images/train\11oexot.jpg
#   Rank 1: pigmented, symmetrical, melanocytic nevus, worsening, symptom
#   Rank 2: lesion, symmetrical, skin lesion
#   Rank 3: image, fingernail skin, fingernail, fingernail, fingertip, skin texture, irregularity, inflammation, thick, irritant
#   Rank 4:
#   Rank 5: image, mouth, dryness, vertical wrinkle, uneven, texture, mouth, upper lip, dry, appearance
#
# Image 66: c:/Users/bhav1/Downloads/dermavqa/images/train\11p3t6t.jpg
#   Rank 1: image, skin, texture, hair follicle, pore faint, moisture, image, mouth, skin texture, seborrheic dermatitis, scratching, daily, depigmentation cream
#   Rank 2: image, visible, skin, discoloration
#   Rank 3: image, visible, lesion discoloration
#   Rank 4: image, skin, image, hair, image, irregular, evidence, patch, irregular area, irritation, localized, skin condition, eczema, contact dermatitis
#   Rank 5: image, image mole, irritated, irritant, excessive, sun exposure
#
# Image 67: c:/Users/bhav1/Downloads/dermavqa/images/train\121719d.jpg
#   Rank 1: keratotic papule, type skin disease, squamous cell carcinoma, diagnosing, squamous cell carcinoma, medical history, manifestation
#   Rank 2: papule, malignant melanoma
#   Rank 3: image, skin, skin, blurred, eyelid bump, stye, problem sign, problem, stye, pimple blister, touch chalazion, eyelid chalazion, stye, pea, skin, case chalazion, eyelid, meibomian gland, blocked, stye, infected, stye, chalazia, stye chalazion, problem, infection, painful, stye chalazion
#   Rank 4: case pityriasis, yeast infection, skin flaky, discoloured, patch, summer, infectious, familymild pityriasis versicolor, skin, pityriasis versicolor, sweat, bathing, case pityriasis, long term, rash, recurrence
#   Rank 5: benign, vascular skin lesion, diagnosed, vascular laser
#
# Image 68: c:/Users/bhav1/Downloads/dermavqa/images/train\11xs1yk.jpg
#   Rank 1: image
#   Rank 2: image, skin, image dryness, lesion, keratotis pilaris
#   Rank 3: image, blotchy red rash rash, image, raised, texture, small, abnormality, rash case urticaria, flea, bedbug, infested, severe, itching
#   Rank 4: polypoid, protrusion, skin, symptom, skin lesion, malignancy lesion
#   Rank 5: image, concentration redness, visible, reddened area
#
# Image 69: c:/Users/bhav1/Downloads/dermavqa/images/train\11l2lpp.jpg
#   Rank 1: image, vermilion border lip, skin skin, lip, contact dermatitis
#   Rank 2: image, skin, area redness, visible pore, mouth, nasolabial fold, faint hyperpigmentation, freckle
#   Rank 3: image, dry, discolored, discoloration, inflammation, inflammatory, skin rest, white discoloration, sign kidney disease, history
#   Rank 4: image, skin, uneven, patch, image, skin texture, hair, visible, dry skin, xerosis, dryness, atopic dermatitis, dry skin, excessive, excessive, bathing, aggravating factor, air, summer, prolonged, hydration, bathing, itchy, skin thicker, irritant
#   Rank 5: lower limb, skin lesion, skin lesion, benign
#
# Image 70: c:/Users/bhav1/Downloads/dermavqa/images/train\11kgolw.jpg
#   Rank 1: pigmented, nevus pigmented nevus, benign tumor skin, excessive, symptom
#   Rank 2: disease progression, medical history, pigment deposition disorder, melanoma, essential, effective
#   Rank 3: black papule, symmetrical, melanocytic nevus
#   Rank 4: melanocytic nevus seborrheic keratosis
#   Rank 5: image, skin, ingrown, hair, ingrown, hair, hair, infection, hair, shave, hair, pat, skin, skin, skin, moisture, skin type, carriage, persistent
#
# Image 71: c:/Users/bhav1/Downloads/dermavqa/images/train\120za8m.jpg
#   Rank 1: melanocytic nevus, malignant melanoma
#   Rank 2: physical examination
#   Rank 3: wrinkle area, skin tag, benign, overgrowth, benign, symptomatic
#   Rank 4: image, vermilion border lip, skin skin, lip, contact dermatitis
#   Rank 5: onychomycosis, nail disease, irregular, white spot, fungal infection, nutritional deficiency
#
# Image 72: c:/Users/bhav1/Downloads/dermavqa/images/train\11wozho.jpg
#   Rank 1: image, skin, inflamed, wart corn, wearing, soft sol
#   Rank 2: image, skin image, wearing, red painful, fall time part
#   Rank 3: image, toenail discoloration, abnormality, discoloration, healthy, smooth surface, natural curvature, skin, leakage, impact, pressure blood vessel, leakage, failure, infection
#   Rank 4: patch, diagnosis pityriasis, skin tumor, medical history, diagnosis pityriasis, chronic inflammatory skin condition, red patch scale itching, skin tumor, skin benign, lipoma malignant, skin cancer
#   Rank 5: redness, skin tumor, medical history
#
# Image 73: c:/Users/bhav1/Downloads/dermavqa/images/train\zem705.jpg
#   Rank 1: image, skin, left shoulder blade, skin, image case, herpes zoster, localised, rash, varicella chickenpox, herpes zoster, herpes zoster, weak, pain, rash, secondary infection, symptom, herpes zoster aciclovir, time daily, prescribed
#   Rank 2: patch, melanocytic nevus, histopathological, skin lesion
#   Rank 3: image, scalp, patch, hair follicle, patch, base hair shaft, skin, visible redness, inflammation, irregularity, hair, dark, hair breakage, visible area
#   Rank 4: image, patch, irregular, palm skin, pink, patch, hair, patch, eczema, contact dermatitis
#   Rank 5: sebaceous cyst, skin condition, blockage, sebaceous gland duct
#
# Image 74: c:/Users/bhav1/Downloads/dermavqa/images/train\11u1n4p.jpg
#   Rank 1: red papule, medical history, physical examination, histopathological
#   Rank 2: image, area redness, patch, appearance, dandruff psoriasis, fungal infection, eczema, history, topical antidandruff
#   Rank 3: image, dark, pupil, skin, texture, image, image, skin
#   Rank 4: image, chapped, lip, appearance, left upper lip vermilion border edge lip, skin, hair, faint, dryness, lip color, irritant
#   Rank 5: irregularly, seborrheic keratosis, basal cell carcinoma, melanoma
#
# Image 75: c:/Users/bhav1/Downloads/dermavqa/images/train\11mgn2f.jpg
#   Rank 1: melanocytic nevus, malignant melanoma
#   Rank 2: image, skin, pink, natural complexion, hair, skin blue, viral infection
#   Rank 3: keratotic papule, upper limb, skin condition, keratotic papule scale skin, medical history, physical examination, skin, histopathology
#   Rank 4: image, skin, texture, discoloration, patch, discolored, patch, patch, patch, raised, texture, irritation, discolored, rash, scratching, biopsy
#   Rank 5: image, skin, hair, malformed, lymphangioma, circumscriptum, secondary infection
#
# Image 76: c:/Users/bhav1/Downloads/dermavqa/images/train\11jey35.jpg
#   Rank 1: image, foot, dryness, texture, skin dryness, toe, yellow discoloration, thickened, increased, combination, athlete, foot retention hyperkeratosis
#   Rank 2: image, skin, texture, visible, visible redness, irregularity, body hair, mole
#   Rank 3: image, skin, left shoulder blade, skin, image case, herpes zoster, localised, rash, varicella chickenpox, herpes zoster, herpes zoster, weak, pain, rash, secondary infection, symptom, herpes zoster aciclovir, time daily, prescribed
#   Rank 4: sebaceous cyst, skin condition, blockage, sebaceous gland duct
#   Rank 5: pigmented, melanocytic, benign, worsening, symptom
#
# Image 77: c:/Users/bhav1/Downloads/dermavqa/images/train\o4dfho.jpg
#   Rank 1: atrophic, decreased, skin, skin thinning, increased, skin texture, diagnosing, atrophic patch, patient history, disease
#   Rank 2: pigmented, melanocytic, benign, worsening, symptom
#   Rank 3: image, skin, image, hair, image, irregular, evidence, patch, irregular area, irritation, localized, skin condition, eczema, contact dermatitis
#   Rank 4: skin tumor, actinic keratosis, histopathological
#   Rank 5: image, skin, skin texture, mole
#
# Image 78: c:/Users/bhav1/Downloads/dermavqa/images/train\11qij8h.jpg
#   Rank 1: inadequate, image
#   Rank 2: image, neck, flushed red, skin, visible, texture, skin, pattern redness, visible area, wearing, eruption, eruption, folliculitis, infection obstruction, appearance, acneiform eruption, hormonal, metabolic abnormality, drug reaction, genetic disorder, acneiform eruption, discontinued, residual, acneiform eruption, fungal infection
#   Rank 3: image, skin, skin, coloration, dermatitis, wear
#   Rank 4: image, fingernail skin, fingernail, fingernail, fingertip, skin texture, irregularity, inflammation, thick, irritant
#   Rank 5: case rosacea, rosacea, chronic inflammatory skin condition, age, rosacea, persistent, facial redness, relapsing, symptom controlled, depression hypertension, cardiovascular disease, rheumatoid arthritis, helicobacter pylorus infection, ulcerative colitis, dementia, trigger, mild, protection, exfoliants, aggravate, appearance, redness, vascular laser, oral, oral, low dose refractory disease, rosacea, chronic disease, relapsing, symptom
#
# Image 79: c:/Users/bhav1/Downloads/dermavqa/images/train\11n5y4z.jpg
#   Rank 1: image, combination, medical history, symptom, physical examination
#   Rank 2: image, skin skin, eyelid small, arch, skin, texture, eyelid, inadequate, sleep deprivation, increase, hyaluronic acid
#   Rank 3: itchy, skin itchy, skin, dry skin, atopic dermatitis, contact dermatitis, hyaluronic acid bee, improve, defect, itching
#   Rank 4: image, skin, left shoulder blade, skin, image case, herpes zoster, localised, rash, varicella chickenpox, herpes zoster, herpes zoster, weak, pain, rash, secondary infection, symptom, herpes zoster aciclovir, time daily, prescribed
#   Rank 5: image, skin heel, thickened, friction
#
# Image 80: c:/Users/bhav1/Downloads/dermavqa/images/train\xnd03l.jpg
#   Rank 1: image, texture, visible, nose cluster, bridge nose, appearance, skin, mild redness, irritation, laser therapy, effective
#   Rank 2: image, skin, visible, lesion, skin, discoloration, lesion
#   Rank 3: nodule, skin disorder, infection, malignant condition, appropriate
#   Rank 4: image, pigmentation skin, reddened, patch, white skin, redness, blotchy, appearance, irregular, man, facial hair, skin, photodermatoses, sun exposed area, sign, prolonged, photosensitivity, disease entity, exogenous, photodermatoses, phototoxic photoallergic reaction, photosensitiser, drug photocontact dermatitis, autoimmune disease, lupus erythematosus, dermatomyositis, photosensitivity, photosensitivity, disorder, summer, effective, skin, indoors, oral
#   Rank 5: image, scalp, hair hair, itchy, cyst seborrheic, keratoses, mole, skin cancer, stop itching, damaged, skin, biopsy
#
# Image 81: c:/Users/bhav1/Downloads/dermavqa/images/train\11o42j5.jpg
#   Rank 1: image, foot, smooth surface, ball, skin, skin sole, dry, texture, ball, pressure, soft sol
#   Rank 2: skin, histopathology
#   Rank 3: image, skin image, hair, eczema, fungal infection, irritant, clothing
#   Rank 4: dry thickened, cracking, hard skin
#   Rank 5: image, lesion, thickened, skin
#
# Image 82: c:/Users/bhav1/Downloads/dermavqa/images/train\1281whp.jpg
#   Rank 1: image, red inflamed, area redness, acne acne, adult, sensitive, skin, dry skin, oily skin, skin irritation, topical acne
#   Rank 2: image, white discoloration, irregular, longitudinal melanonychia, dark line, fingernail, cell mole, skin cancer, biopsy
#   Rank 3: image, fingernail skin fingertip, dry cracked, yellowish discoloration, skin, inflamed, fingernail, texture, wart periungual wart wart form, fingernail, pretty painful, infection, human papillomavirus hpv hpv, skin, wart, subungual wart, pain, wart
#   Rank 4: case acneiform, eruption, eruption, folliculitis, infection obstruction, appearance, acneiform eruption, hormonal, metabolic abnormality, drug reaction, genetic disorder, acneiform eruption, discontinued, residual, acneiform eruption
#   Rank 5: black papule, excessive, skin, thickening stratum corneum, affected
#
# Image 83: c:/Users/bhav1/Downloads/dermavqa/images/train\z22glp.jpg
#   Rank 1: image, skin, coloration, texture, skin, uneven, dryness
#   Rank 2: case urticaria, flea, bedbug, infested, trigger, severe, itching
#   Rank 3:
#   Rank 4: image, vermilion border lip, skin skin, lip, contact dermatitis
#   Rank 5: image, irregularity, bump discoloration, apparent eczema, dry, daily, irritant
#
# Image 84: c:/Users/bhav1/Downloads/dermavqa/images/train\120ybza.jpg
#   Rank 1: papule, melanocytic, skin lesion, increase, melanocyte skin, benign
#   Rank 2: image, wrist, wrinkle fine line, visible, irregularity, image, car, changing, lesion, biopsy
# ...
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\145.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\57.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\95.png
#
# Text 391: seborrheic keratosis, skin condition, excessive, skin, abnormal, blackhead
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\61.png
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\128.png
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\10i4z2b.jpg
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\88.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\11z5ys1.jpg
#
# Text 392: presentation, type skin condition, discoid lupus erythematosus, discoid lupus erythematosus, autoimmune disease, skin manifestation, keratotic papule, medical history, physical examination, histopathological, immunosuppressant
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\11zvn4m.png
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\11wsghy.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\11oo3mv.jpg
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\zmsedx.jpg
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\153.png
#
# Text 393: medical history, physical examination, histopathological
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\11j6l9b.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\11k2jwb.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\126oxq9.jpg
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\123yl8i.jpg
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\11kavj4.jpg
#
# Text 394: black papule, seborrheic keratosis
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\11kavj4.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\11ejw2c.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\11rbig0.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\8.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\96.png
#
# Text 395: melanocytic nevus, malignant melanoma
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\11f4mm5.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\11ffqym.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\132.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\11vztbn.jpg
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\146.png
#
# Text 396: polypoid, protrusion, skin, symptom, skin lesion, malignancy lesion
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\14.png
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\42.png
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\11v5s95.jpg
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\120oede.jpg
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\1266hp1.jpg
#
# Text 397: foot, skin, lesion, biopsy
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\1244l31.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\97.png
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\122xvv0.jpg
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\11vsbt7.jpg
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\12814gl.jpg
#
# Text 398: hidradenitis hidradenitis, skin condition, lesion skin surface, blockage, sebaceous gland, medical history, physical examination, histopathological
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\153.png
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\zmsedx.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\105.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\11zvn4m.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\gqr1w3.jpg
#
# Text 399: physical examination, vasculitis, effective
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\11ie3p4.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\11vgyp5.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\123yl8i.jpg
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\27.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\zmsedx.jpg
#
# Text 400: vascular tumor cutaneous lupus erythematosus, urticaria, medical history, physical examination, histopathological
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\23.png
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\11oo3mv.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\118.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\12.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\28.png
#
# Text 401: presentation, skin tumor, seborrheic keratosis, melanocytic nevus
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\11ejw2c.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\94.png
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\11ie3p4.jpg
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\45.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\11wsghy.jpg
#
# Text 402: polypoid, protrusion, skin, benign
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\2.png
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\31.png
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\102.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\123n04s.jpg
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\g3e65p.jpg
#
# Text 403: skin tag, skin tag, benign, skin lesion, raised, skin tag, benign, lesion
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\ih99w9.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\123.png
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\9.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\21.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\1162b7j.jpg
#
# Text 404: earlobe, seborrheic keratosis, overgrowth, skin
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\123yl8i.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\81.png
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\27.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\11wsghy.jpg
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\11z5ys1.jpg
#
# Text 405: skin disorder, folliculitis furuncle, medical history, physical examination, histopathological
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\81.png
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\121u099.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\121dqgq.jpg
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\11zvn4m.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\11kj4o4.jpg
#
# Text 406: presentation, small papule, color skin, medical history, skin lesion
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\120.png
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\96.png
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\1162b7j.jpg
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\9.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\1262c8t.jpg
#
# Text 407: hairline, skin tumor, medical history, skin tumor, benign, lipoma, malignant, malignant melanoma
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\144.png
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\94.png
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\13.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\1276gm6.jpg
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\11f2wms.jpg
#
# Text 408: symmetrical, skin tag, skin tag, benign, skin lesion, medical advice
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\146.png
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\11vzpyw.png
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\1222mry.jpg
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\46.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\11vztbn.jpg
#
# Text 409: wrinkle area, skin tag, benign, overgrowth, benign, symptomatic
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\121u099.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\146.png
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\124sycc.jpg
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\11j6l9b.jpg
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\11f4mm5.jpg
#
# Text 410: smooth nodule, presentation, benign, lesion, malignancy, medical history, clinical symptom, nodule
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\35.png
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\124sycc.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\70.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\152.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\11jj25a.jpg
#
# Text 411:
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\11ie3p4.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\11wsghy.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\gxs8me.jpg
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\66.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\98.png
#
# Text 412: red papule, furuncle furuncle, skin infection, staphylococcus aureus, redness, swelling pain, warmth, drainage, oral
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\31.png
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\124zivv.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\123yl8i.jpg
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\11j7e82.jpg
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\10cx1if.jpg
#
# Text 413: symptom, skin tag, skin tag, benign, discomfort
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\1283khx.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\46.png
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\124sycc.jpg
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\12.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\11vsbt7.jpg
#
# Text 414: symmetrical, appearance, seborrheic keratosis, nevus
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\11i296a.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\11kavj4.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\2.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\152.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\1283khx.jpg
#
# Text 415: irregular, nodule, seborrheic keratosis melanoma, seborrheic keratosis, skin condition, irregular, head neck melanoma, malignant, skin tumor, irregularly, pigmented, patch
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\1162b7j.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\1251tnr.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\11qop8i.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\90.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\11vzpyw.png
#
# Text 416: malignant skin tumor, medical history, histopathological
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\102.png
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\122xd14.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\11q1bgc.jpg
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\11i296a.jpg
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\145.png
#
# Text 417: smooth nodule, vascular tumor hemangioma, medical history, physical examination, histopathological
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\zmsedx.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\11j7e82.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\105.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\11wsghy.jpg
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\11tpn0n.jpg
#
# Text 418: image
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\14.png
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\103.png
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\18.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\116.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\108am5i.jpg
#
# Text 419: wart, skin condition
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\11v2egh.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\41.png
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\23.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\28.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\1203l30.jpg
#
# Text 420: keratotic papule, upper limb, skin condition, keratotic papule scale skin, medical history, physical examination, skin, histopathology
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\153.png
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\123yl8i.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\11vgyp5.jpg
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\11mgn2f.jpg
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\124zivv.jpg
#
# Text 421: pigmented, melanocytic, benign, worsening, symptom
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\158.png
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\11t9sqx.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\12814gl.jpg
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\11kfi6v.jpg
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\11vsbt7.jpg
#
# Text 422: irregularly, seborrheic keratosis, medical history
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\11kavj4.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\11ejw2c.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\11rbig0.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\8.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\96.png
#
# Text 423: sebaceous cyst squamous cell carcinoma, melanoma, medical history, lesion
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\11rljbj.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\11vztbn.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\113.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\118zkgw.jpg
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\11tpn0n.jpg
#
# Text 424: blueblack, melanoma, malignant skin tumor
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\11rljbj.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\11z5xpa.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\129.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\11q1bgc.jpg
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\66.png
#
# Text 425: folliculitis, follicular cyst, medical history, physical examination, skin, histopathological
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\11f4mm5.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\124sycc.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\11zvn4m.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\128.png
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\ih99w9.jpg
#
# Text 426: red papule, medical history, physical examination, histopathological
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\11zvn4m.png
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/images/train\11u1n4p.jpg
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\162.png
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\11wsghy.jpg
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/images/train\11pprbi.jpg
#
# Text 427: skin tumor, medical history, physical examination, histopathological
#   Rank 1: c:/Users/bhav1/Downloads/dermavqa/images/train\1274ox7.jpg
#   Rank 2: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\78.png
#   Rank 3: c:/Users/bhav1/Downloads/dermavqa/images/train\1230249.jpg
#   Rank 4: c:/Users/bhav1/Downloads/dermavqa/images/train\1266hp1.jpg
#   Rank 5: c:/Users/bhav1/Downloads/dermavqa/SkinCAP/skincap\21.png

# %%
model_hf
# Out:
# CLIPModel(
#   (text_model): CLIPTextTransformer(
#     (embeddings): CLIPTextEmbeddings(
#       (token_embedding): Embedding(49408, 768)
#       (position_embedding): Embedding(77, 768)
#     )
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x CLIPEncoderLayer(
#           (self_attn): CLIPAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (layer_norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (layer_norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (vision_model): CLIPVisionTransformer(
#     (embeddings): CLIPVisionEmbeddings(
#       (patch_embedding): Conv2d(3, 1024, kernel_size=(14, 14), stride=(14, 14), bias=False)
#       (position_embedding): Embedding(257, 1024)
#     )
#     (pre_layrnorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-23): 24 x CLIPEncoderLayer(
#           (self_attn): CLIPAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (layer_norm1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           )
#           (layer_norm2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (post_layernorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (visual_projection): Linear(in_features=1024, out_features=768, bias=False)
#   (text_projection): Linear(in_features=768, out_features=768, bias=False)
# )

# %%
from sklearn.metrics import roc_auc_score

def compute_auc(similarity_matrix, num_samples):
    ground_truth = torch.eye(num_samples).to(similarity_matrix.device)
    similarity_flat = similarity_matrix.flatten().cpu().numpy()
    ground_truth_flat = ground_truth.flatten().cpu().numpy()

    auc_score = roc_auc_score(ground_truth_flat, similarity_flat)
    return auc_score

auc_score = compute_auc(similarity_matrix, len(image_features))
print(f"AUC Score: {auc_score:.4f}")
# Out:
# AUC Score: 0.7960
